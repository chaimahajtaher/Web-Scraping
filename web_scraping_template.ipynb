# %% [markdown]
# # Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# # HTTP Request

# %% [markdown]
# # store website in variable

# %%
website = 'https://www.cars.com/shopping/results/?stock_type=new_cpo&makes%5B%5D=volkswagen&models%5B%5D=&list_price_max=&maximum_distance=all&zip='

# %% [markdown]
# # Get Request

# %%
response = requests.get(website)

# %% [markdown]
# # Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# # Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="ep-theme-cars" lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title data-suffix=" | Cars.com">New and Certified Used Volkswagen for Sale | Cars.com</title>
# <meta content="Shop Volkswagen vehicles for sale at Cars.com. Research, compare, and save listings, or contact sellers directly from 10,000+ Volkswagen models nationwide." name="description"/>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="Cars.com" property="og:site_name"/>
# <meta content="website" property="og:type"/>
# <meta content="New and Certified Used Volkswagen for Sale | Cars.com" property="og:title"/>
# <meta content="https://www.cars.com/shopping/results" property="og:url"/>
# ...

# %% [markdown]
# # Results

# %%
results = soup.find_all('div', {'class' : 'vehicle-card'})

# %%
len(results)
# Out:
# 21

# %%
results[0]
# Out:
# <div class="vehicle-card inventory-ad" data-inventory-ad="true" data-koddi-click-tracking-url="https://cars.koddi.io/event-collection/beacon?action=click&amp;trackingData={trackingData}&amp;rank={rank}&amp;clientName=Cars&amp;beaconIssued=2023-02-14T12:45:34Z" data-koddi-impression-tracking-url="https://cars.koddi.io/event-collection/beacon?action=impression&amp;trackingData={trackingData}&amp;rank={rank}&amp;ts={ts}&amp;clientName=Cars&amp;beaconIssued=2023-02-14T12:45:34Z" data-koddi-listing-id="e5f55f7f-0a23-4dca-a7de-47f27979ac35" data-koddi-tracking-data="..." data-koddi-tracking-guid="1900d81e-9aa6-44a8-bfe2-d46f574e9e32" data-koddi-user-guid="" data-listing-id="e5f55f7f-0a23-4dca-a7de-47f27979ac35" data-tracking-id="1" data-tracking-type="srp-vehicle-card" id="vehicle-card-e5f55f7f-0a23-4dca-a7de-47f27979ac35-sponsored" phx-hook="VehicleCard" phx-target="7">
# ...

# %% [markdown]
# # Target necessary data

# %%
# Name
# Mileage
# Dealer Name
# Rating
# Rating Count
# Price

# %% [markdown]
# # Name

# %%
results[0].find('h2').get_text()
# Out:
# '2023 Volkswagen Atlas 3.6L SE w/Technology'

# %%
results[1].find('h2').get_text()
# Out:
# '2023 Volkswagen Taos 1.5T SE'

# %%
results[10].find('h2').get_text()
# Out:
# '2023 Volkswagen Tiguan 2.0T SEL R-Line'

# %% [markdown]
# # Mileage

# %%
print(results[0].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[1].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[2].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[3].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[4].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[5].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[6].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[7].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[8].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[9].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[10].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[11].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[12].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[13].find('div', {'class':'mileage'}))
# Out:
# None

# %%
print(results[14].find('div', {'class':'mileage'}))
# Out:
# None

# %% [markdown]
# # Dealer-name

# %%
print(results[0].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[1].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[2].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[3].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[4].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[5].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[6].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[7].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[8].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[9].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[10].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[11].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[12].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[13].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[14].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[15].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[16].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[17].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[18].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[19].find('div', {'class':'dealer-name'}).get_text().strip())
print(results[20].find('div', {'class':'dealer-name'}).get_text().strip())
# Out:
# Rusty Wallis Volkswagen
# Lafayette Volkswagen
# Douglass Mazda
# Reydel Volkswagen of Edison
# Zimbrick Volkswagen
# Gossett Porsche VW
# Hendrick Volkswagen Frisco
# Beechmont Volkswagen
# Volkswagen of Downtown Chicago
# Lewisville Volkswagen
# Jack Daniels Volkswagen
# Tom Wood Volkswagen
# Zimbrick Volkswagen
# Carousel Audi Mercedes-Benz Volkswagen
# Orr Volkswagen of Texarkana
# Toyota Volkswagen of Wooster
# Prestige Volkswagen
# Alexandria VW
# Leesburg Volkswagen
# Village Volkswagen of Chattanooga
# Lou Bachrodt Auto Mall

# %% [markdown]
# # Rating

# %%
results[0].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.8'

# %%
results[6].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.6'

# %%
results[8].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.5'

# %%
results[9].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.8'

# %%
results[10].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.7'

# %%
results[11].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.3'

# %%
results[13].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.8'

# %%
results[17].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.7'

# %%
results[18].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.9'

# %%
results[19].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.9'

# %%
results[20].find('span', {'class':'sds-rating__count'}).get_text()
# Out:
# '4.8'

# %% [markdown]
# # Rating Count

# %%
results[0].find('span', {'class':'sds-rating__link'}).get_text()
# Out:
# '(716 reviews)'

# %% [markdown]
# # Price

# %%
results[0].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$43,855'

# %%
results[1].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$29,392'

# %%
results[2].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$32,228'

# %%
results[3].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$46,205'

# %%
results[20].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$39,998'

# %%
results[19].find('span', {'class':'primary-price'}).get_text()
# Out:
# '$53,382'

# %% [markdown]
# # Put everything together inside a For-Loop

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for result in results:
    
    # name
    try:
        name.append(result.find('h2').get_text()) 
    except:
        name.append('n/a')
    
    # mileage
    try:
        mileage.append(result.find('div', {'class':'mileage'}).get_text())
    except:
        mileage.append('n/a')
    
    # dealer_name
    try:
        dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
    except:
        dealer_name.append('n/a')
        
    # rating
    try:
        rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
    except:
        rating.append('n/a')
    
    # review_count
    try:
        review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
    except:
        review_count.append('n/a')
    
    #price 
    try:
        price.append(result.find('span', {'class':'primary-price'}).get_text())
    except:
        price.append('n/a')

# %% [markdown]
# # Create Pandas Dataframe

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                                  Name     Mileage  \
# 0          2023 Volkswagen Atlas 3.6L SE w/Technology         n/a
# 1                        2023 Volkswagen Taos 1.5T SE         n/a
# 2                      2023 Volkswagen Tiguan 2.0T SE         n/a
# 3                            2022 Volkswagen ID.4 Pro         n/a
# 4                          2022 Volkswagen ID.4 Pro S         n/a
# 5                          2023 Volkswagen ID.4 Pro S         n/a
# 6          2022 Volkswagen Atlas 3.6L SE w/Technology         n/a
# 7   2023 Volkswagen Atlas Cross Sport 3.6 V6 SEL R...         n/a
# 8                      2022 Volkswagen Tiguan 2.0T SE         n/a
# 9       2023 Volkswagen Atlas 3.6L SEL Premium R-Line         n/a
# 10             2023 Volkswagen Tiguan 2.0T SEL R-Line         n/a
# 11                   2023 Volkswagen Jetta 1.5T Sport         n/a
# 12                         2022 Volkswagen ID.4 Pro S         n/a
# ...

# %%
#Data cleaning
car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))

# %%
# dataframe updated
car_dealer
# Out:
#                                                  Name     Mileage  \
# 0          2023 Volkswagen Atlas 3.6L SE w/Technology         n/a
# 1                        2023 Volkswagen Taos 1.5T SE         n/a
# 2                      2023 Volkswagen Tiguan 2.0T SE         n/a
# 3                            2022 Volkswagen ID.4 Pro         n/a
# 4                          2022 Volkswagen ID.4 Pro S         n/a
# 5                          2023 Volkswagen ID.4 Pro S         n/a
# 6          2022 Volkswagen Atlas 3.6L SE w/Technology         n/a
# 7   2023 Volkswagen Atlas Cross Sport 3.6 V6 SEL R...         n/a
# 8                      2022 Volkswagen Tiguan 2.0T SE         n/a
# 9       2023 Volkswagen Atlas 3.6L SEL Premium R-Line         n/a
# 10             2023 Volkswagen Tiguan 2.0T SEL R-Line         n/a
# 11                   2023 Volkswagen Jetta 1.5T Sport         n/a
# 12                         2022 Volkswagen ID.4 Pro S         n/a
# ...

# %% [markdown]
# **Output in Excel**

# %%
car_dealer.to_excel('car_dealer_single_page.xlsx', index=False)

# %% [markdown]
# # Pagination : multiple pages

# %%
name = []
mileage = []
dealer_name = []
rating = []
review_count = []
price = []

for i in range (1,21):
    
    # website in variable
    website = 'https://www.cars.com/shopping/results/?page='+ str(i) +'&page_size=20&dealer_id=&keyword=&list_price_max=&list_price_min=&makes[]=volkswagen&maximum_distance=all&mileage_max=&sort=best_match_desc&stock_type=cpo&year_max=&'

    
    # request to website
    response = requests.get(website)
    
    # soup object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # results
    results = soup.find_all('div', {'class' : 'vehicle-card'})
    
    # loop through results
    for result in results:
    
        # name
        try:
            name.append(result.find('h2').get_text()) 
        except:
            name.append('n/a')

        # mileage
        try:
            mileage.append(result.find('div', {'class':'mileage'}).get_text())
        except:
            mileage.append('n/a')

        # dealer_name
        try:
            dealer_name.append(result.find('div', {'class':'dealer-name'}).get_text().strip())
        except:
            dealer_name.append('n/a')

        # rating
        try:
            rating.append(result.find('span', {'class':'sds-rating__count'}).get_text())
        except:
            rating.append('n/a')

        # review_count
        try:
            review_count.append(result.find('span', {'class':'sds-rating__link'}).get_text())
        except:
            review_count.append('n/a')

        #price 
        try:
            price.append(result.find('span', {'class':'primary-price'}).get_text())
        except:
            price.append('n/a')

# %%
# dictionary
car_dealer = pd.DataFrame({'Name': name, 'Mileage':mileage, 'Dealer Name':dealer_name,
                                'Rating': rating, 'Review Count': review_count, 'Price': price})

# %%
car_dealer
# Out:
#                                                   Name     Mileage  \
# 0           2019 Volkswagen Atlas 3.6L SE w/Technology  25,133 mi.
# 1    2022 Volkswagen Atlas Cross Sport 3.6L V6 SE w...   5,246 mi.
# 2                        2022 Volkswagen Atlas 2.0T SE  27,361 mi.
# 3                     2019 Volkswagen Jetta GLI 2.0T S  25,587 mi.
# 4    2020 Volkswagen Atlas Cross Sport 2.0T SE w/Te...  28,658 mi.
# ..                                                 ...         ...
# 403                      2022 Volkswagen Atlas 2.0T SE  15,780 mi.
# 404          2021 Volkswagen Atlas Cross Sport 2.0T SE  29,505 mi.
# 405      2022 Volkswagen Atlas Cross Sport 3.6L V6 SEL  22,866 mi.
# 406         2019 Volkswagen Atlas 3.6L SE w/Technology  30,263 mi.
# 407                     2022 Volkswagen Tiguan 2.0T SE   5,748 mi.
#
#                                 Dealer Name Rating     Review Count    Price
# 0                Volkswagen of Palm Springs    3.9     (85 reviews)  $29,987
# ...

# %%
car_dealer['Review Count'] = car_dealer['Review Count'].apply(lambda x: x.strip('reviews)').strip('('))

# %%
car_dealer
# Out:
#                                                   Name     Mileage  \
# 0           2019 Volkswagen Atlas 3.6L SE w/Technology  25,133 mi.
# 1    2022 Volkswagen Atlas Cross Sport 3.6L V6 SE w...   5,246 mi.
# 2                        2022 Volkswagen Atlas 2.0T SE  27,361 mi.
# 3                     2019 Volkswagen Jetta GLI 2.0T S  25,587 mi.
# 4    2020 Volkswagen Atlas Cross Sport 2.0T SE w/Te...  28,658 mi.
# ..                                                 ...         ...
# 403                      2022 Volkswagen Atlas 2.0T SE  15,780 mi.
# 404          2021 Volkswagen Atlas Cross Sport 2.0T SE  29,505 mi.
# 405      2022 Volkswagen Atlas Cross Sport 3.6L V6 SEL  22,866 mi.
# 406         2019 Volkswagen Atlas 3.6L SE w/Technology  30,263 mi.
# 407                     2022 Volkswagen Tiguan 2.0T SE   5,748 mi.
#
#                                 Dealer Name Rating Review Count    Price
# 0                Volkswagen of Palm Springs    3.9          85   $29,987
# ...

# %%
car_dealer.shape
# Out:
# (408, 6)

# %%
#Output in Excel
car_dealer.to_excel('car_dealer_multiple_page.xlsx', index=False)

# %%
#Length of data
print('lenght of data is', len(car_dealer))
# Out:
# lenght of data is 408

# %%
print(f"The dataset contains {car_dealer.shape[0]} observations, from which we have {car_dealer.shape[1]} attributes")
# Out:
# The dataset contains 408 observations, from which we have 6 attributes

# %%
#Data information
car_dealer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 408 entries, 0 to 407
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          408 non-null    object
#  1   Mileage       408 non-null    object
#  2   Dealer Name   408 non-null    object
#  3   Rating        408 non-null    object
#  4   Review Count  408 non-null    object
#  5   Price         408 non-null    object
# dtypes: object(6)
# memory usage: 19.2+ KB

# %%
car_dealer.nunique()
# Out:
# Name            168
# Mileage         402
# Dealer Name     158
# Rating           26
# Review Count    144
# Price           358
# dtype: int64

# %%
print("Column    Missing values")
print("-----------------------------")
car_dealer.isnull().sum()
# Out:
# Column    Missing values
# -----------------------------
# Name            0
# Mileage         0
# Dealer Name     0
# Rating          0
# Review Count    0
# Price           0
# dtype: int64

# %%
car_dealer.duplicated().sum()
# Out:
# 2

# %%
#matrix of features distribution
import missingno as msno
msno.matrix(car_dealer)
# Out:
# <AxesSubplot:>
